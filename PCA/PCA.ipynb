# %%
from PCA import *

# %%
x = load_and_center_dataset('YaleB_32x32.npy')
S = get_covariance(x)
for num_eig in [2, 5, 10, 100]:
    Lambda, U = get_eig(S, num_eig)
    projection = project_image(x[0], U)
    display_image(x[0], projection)
